# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install pennylane pennylane-qiskit

# %%
df=pd.read_csv('/kaggle/input/mental-health-social-media/Mental-Health-Twitter.csv')
df

# %%
# !pip install qiskit
# !pip install qiskit_machine_learning
# !pip install datasets
# !pip install pylatexenc

# %% [markdown]
# # **DistilBERT**

# %%
# !pip install pennylane
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import transformers
from transformers import AutoModel, BertTokenizerFast
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
from sklearn.metrics import (
    roc_curve, roc_auc_score, classification_report, confusion_matrix
)
from sklearn.preprocessing import label_binarize
import pennylane as qml
from pennylane import numpy as pnp
import re
import warnings
import re
import nltk
from nltk.corpus import stopwords
warnings.filterwarnings('ignore')
# Label encoding for 'status' column
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoModel
import pennylane as qml
# Convert data to PyTorch DataLoader format
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
import time
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc
from transformers import get_linear_schedule_with_warmup
from torch.optim import AdamW
from sklearn.model_selection import ParameterSampler
import random
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import torch
from sklearn.preprocessing import label_binarize
import time
import random
import numpy as np
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import get_linear_schedule_with_warmup
from transformers import AutoTokenizer, AutoModel

df = pd.read_csv("/kaggle/input/spam-dataset-qtl/spamdata_v2 (1).csv")
df.head()

df.shape


def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)  # Remove links
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    text = re.sub(r'#\w+', '', text)  # Remove hashtags
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = text.lower()  # Convert to lowercase
    return text

df['cleaned_text'] = df['text'].apply(preprocess_text)

df = df[df['cleaned_text'] != '[deleted]']
df = df[df['cleaned_text'] != '[removed]']

df.head()

# Download NLTK stopwords (only needed once)
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

def clean_statement(statement):
    # Convert to lowercase
    statement = statement.lower()

    # Remove special characters (punctuation, non-alphabetic characters)
    statement = re.sub(r'[^\w\s]', '', statement)

    # Remove numbers (optional, depending on your use case)
    statement = re.sub(r'\d+', '', statement)

    # Tokenize the statement (split into words)
    words = statement.split()

    # Remove stopwords
    words = [word for word in words if word not in stop_words]

    # Rejoin words into a cleaned statement
    cleaned_statement = ' '.join(words)

    return cleaned_statement

# Apply the cleaning function to the 'statement' column
df['cleaned_text'] = df['cleaned_text'].apply(clean_statement)

df


label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])

df.head()

# Check the number of samples per class
class_counts = df['label'].value_counts()
print(class_counts)
# Separate majority and minority classes
class_counts = df['label'].value_counts()
print(class_counts)

majority_class = df['label'].value_counts().idxmax()
minority_class = df['label'].value_counts().idxmin()

df_majority = df[df['label'] == majority_class]
df_minority = df[df['label'] == minority_class]

# Downsample majority to match minority
df_majority_downsampled = df_majority.sample(len(df_minority), random_state=42)

# Combine
df_balanced = pd.concat([df_majority_downsampled, df_minority])

# Shuffle
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

print(df_balanced['label'].value_counts())


class_counts.plot(kind='bar', title='Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.show()

# Initialize the tokenizer and model from Hugging Face
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

tokens = tokenizer.batch_encode_plus(
    df['cleaned_text'].tolist(),
    max_length=128,
    padding="max_length",   # <-- updated
    truncation=True,
    return_tensors="pt"
)

# Convert to tensors
input_ids = torch.tensor(tokens['input_ids'])
attention_masks = torch.tensor(tokens['attention_mask'])
labels = torch.tensor(df['label'].values)

# Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(input_ids, labels, test_size=0.2)
train_masks, val_masks, _, _ = train_test_split(attention_masks, input_ids, test_size=0.2)


train_data = TensorDataset(train_inputs, train_masks, train_labels)
val_data = TensorDataset(val_inputs, val_masks, val_labels)

train_dataloader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=32)
val_dataloader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=32)

# Create a quantum node (circuit)
dev = qml.device("default.qubit", wires=2)  # or 'default.qubit'

@qml.qnode(dev)
@qml.qnode(dev)
def quantum_circuit(weights, inputs):
    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RX(inputs[0], wires=0)
    qml.RY(inputs[1], wires=1)

    qml.CNOT(wires=[0, 1])

    qml.RZ(weights[0], wires=0)
    qml.RZ(weights[1], wires=1)

    return qml.expval(qml.PauliZ(0))

class QBiLSTM(nn.Module):
    def __init__(self):
        super(QBiLSTM, self).__init__()

        self.bert = AutoModel.from_pretrained("distilbert-base-uncased")

        # 🔁 BiLSTM instead of LSTM
        self.bilstm = nn.LSTM(
            input_size=768,
            hidden_size=128,
            batch_first=True,
            bidirectional=True
        )

        # 128 × 2 because BiLSTM
        self.fc = nn.Linear(256, 2)

    def quantum_layer(self, inputs):
        processed_features = []

        for feature_vector in inputs:
            features_for_quantum = feature_vector[:2]
            q_out = quantum_circuit(
                torch.randn(2, dtype=torch.float32),
                features_for_quantum
            )
            processed_features.append(q_out)

        return torch.stack(processed_features).unsqueeze(1)

    def forward(self, input_ids, attention_mask):
        bert_output = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # BiLSTM output
        lstm_output, _ = self.bilstm(bert_output.last_hidden_state)

        # Last timestep (batch, 256)
        last_hidden = lstm_output[:, -1, :]

        _ = self.quantum_layer(last_hidden)

        # Classification
        output = self.fc(last_hidden)
        return output


model = QBiLSTM()

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define hyperparameter search space
param_grid = {
    'learning_rate': [1e-5, 2e-5, 3e-5, 5e-5],
    'batch_size': [16, 32],
    'epochs': [3, 5, 7]
}

num_samples = 5  
param_list = list(ParameterSampler(param_grid, n_iter=num_samples, random_state=42))

best_model = None
best_val_accuracy = 0.0
best_params = None

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# Loop through each random set of hyperparameters
for idx, params in enumerate(param_list):
    print(f"Testing configuration {idx + 1}: {params}")

    learning_rate = params['learning_rate']
    batch_size = params['batch_size']
    epochs = params['epochs']

    # Define optimizer and scheduler
    optimizer = AdamW(model.parameters(), lr=learning_rate)
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

    for epoch in range(epochs):
        start_time = time.time()
        model.train()
        total_train_loss = 0
        total_train_accuracy = 0

        for batch in train_dataloader:
            b_input_ids, b_input_mask, b_labels = batch

            # Move tensors to the same device
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            optimizer.zero_grad()
            outputs = model(b_input_ids, b_input_mask)
            loss = nn.CrossEntropyLoss()(outputs, b_labels)
            total_train_loss += loss.item()

            logits = outputs.detach().cpu().numpy()
            label_ids = b_labels.cpu().numpy()
            total_train_accuracy += flat_accuracy(logits, label_ids)

            loss.backward()
            optimizer.step()
            scheduler.step()

        avg_train_loss = total_train_loss / len(train_dataloader)
        avg_train_accuracy = total_train_accuracy / len(train_dataloader)

        # Validation
        model.eval()
        total_val_loss = 0
        total_val_accuracy = 0
        all_preds = []
        all_labels = []

        for batch in val_dataloader:
            b_input_ids, b_input_mask, b_labels = batch

            # Move tensors to the same device
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            with torch.no_grad():
                outputs = model(b_input_ids, b_input_mask)
                loss = nn.CrossEntropyLoss()(outputs, b_labels)
                total_val_loss += loss.item()

                logits = outputs.detach().cpu().numpy()
                label_ids = b_labels.cpu().numpy()
                total_val_accuracy += flat_accuracy(logits, label_ids)

                all_preds.extend(np.argmax(logits, axis=1).flatten())
                all_labels.extend(label_ids.flatten())

        avg_val_loss = total_val_loss / len(val_dataloader)
        avg_val_accuracy = total_val_accuracy / len(val_dataloader)
        elapsed_time = time.time() - start_time

        print(f"Epoch {epoch+1} | Train Loss: {avg_train_loss:.4f} | Train Accuracy: {avg_train_accuracy:.4f}")
        print(f"Validation Loss: {avg_val_loss:.4f} | Validation Accuracy: {avg_val_accuracy:.4f}")
        print(f"Time: {elapsed_time:.2f} seconds")

        # Save best model
        if avg_val_accuracy > best_val_accuracy:
            best_val_accuracy = avg_val_accuracy
            best_model = model.state_dict()
            best_params = params
            torch.save(best_model, 'best_model.pth')
            print(f"New best model saved with accuracy: {best_val_accuracy:.4f}")

# Generate classification report
print("Classification Report:")
print(classification_report(all_labels, all_preds))



# Define search space for hyperparameters
epochs = 5
learning_rates = [2e-5, 3e-5, 5e-5]
batch_sizes = [16, 32]
optimizers = ['adamw', 'adam', 'rmsprop', 'sgd']

# Number of random samples to try
num_samples = 5

# Function to calculate accuracy
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# Function to get optimizer
def get_optimizer(optimizer_name, model_parameters, lr):
    if optimizer_name == 'adamw':
        return optim.AdamW(model_parameters, lr=lr)
    elif optimizer_name == 'adam':
        return optim.Adam(model_parameters, lr=lr)
    elif optimizer_name == 'rmsprop':
        return optim.RMSprop(model_parameters, lr=lr)
    elif optimizer_name == 'sgd':
        return optim.SGD(model_parameters, lr=lr)

# Randomly sample hyperparameter combinations
random_hyperparams = [
    {
        "optimizer": random.choice(optimizers),
        "learning_rate": random.choice(learning_rates),
        "batch_size": random.choice(batch_sizes),
    }
    for _ in range(num_samples)
]

best_accuracy = 0
best_params = {}

# Iterate over randomly chosen hyperparameter sets
for params in random_hyperparams:
    optimizer_name = params["optimizer"]
    lr = params["learning_rate"]
    batch_size = params["batch_size"]

    # Initialize data loaders
    train_dataloader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=batch_size)
    val_dataloader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=batch_size)

    # Define optimizer and scheduler
    optimizer = get_optimizer(optimizer_name, model.parameters(), lr)
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

    # Move model to device
    model.to(device)

    for epoch in range(epochs):
        start_time = time.time()

        # Training
        model.train()
        total_train_loss = 0
        total_train_accuracy = 0
        for batch in train_dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids, b_input_mask, b_labels = b_input_ids.to(device), b_input_mask.to(device), b_labels.to(device)

            optimizer.zero_grad()
            outputs = model(b_input_ids, b_input_mask)
            loss = nn.CrossEntropyLoss()(outputs, b_labels)
            total_train_loss += loss.item()

            logits = outputs.detach().cpu().numpy()
            label_ids = b_labels.cpu().numpy()
            total_train_accuracy += flat_accuracy(logits, label_ids)

            loss.backward()
            optimizer.step()
            scheduler.step()

        avg_train_loss = total_train_loss / len(train_dataloader)
        avg_train_accuracy = total_train_accuracy / len(train_dataloader)

        # Validation
        model.eval()
        total_val_loss = 0
        total_val_accuracy = 0
        for batch in val_dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids, b_input_mask, b_labels = b_input_ids.to(device), b_input_mask.to(device), b_labels.to(device)

            with torch.no_grad():
                outputs = model(b_input_ids, b_input_mask)
                loss = nn.CrossEntropyLoss()(outputs, b_labels)
                total_val_loss += loss.item()

                logits = outputs.detach().cpu().numpy()
                label_ids = b_labels.cpu().numpy()
                total_val_accuracy += flat_accuracy(logits, label_ids)

        avg_val_loss = total_val_loss / len(val_dataloader)
        avg_val_accuracy = total_val_accuracy / len(val_dataloader)

        elapsed_time = time.time() - start_time

        print(f"Optimizer: {optimizer_name} | Learning Rate: {lr} | Batch Size: {batch_size}")
        print(f"Epoch {epoch+1}")
        print(f"Train Loss: {avg_train_loss:.4f} | Train Accuracy: {avg_train_accuracy:.4f}")
        print(f"Validation Loss: {avg_val_loss:.4f} | Validation Accuracy: {avg_val_accuracy:.4f}")
        print(f"Time: {elapsed_time:.2f} seconds")
        print("-" * 50)

        # Update best parameters if validation accuracy improves
        if avg_val_accuracy > best_accuracy:
            best_accuracy = avg_val_accuracy
            best_params = {"optimizer": optimizer_name, "learning_rate": lr, "batch_size": batch_size}

print(f"Best Validation Accuracy: {best_accuracy:.4f}")
print(f"Best Parameters: Optimizer = {best_params['optimizer']}, Learning Rate = {best_params['learning_rate']}, Batch Size = {best_params['batch_size']}")
# Out:
# Collecting pennylane
#   Downloading pennylane-0.44.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane)
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.44 (from pennylane)
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.0rc2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane)
#   Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.44.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 56.6 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 55.1 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 84.8 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.1 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 16.1 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 118.4 MB/s eta 0:00:0000:01
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 pennylane-0.44.0 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.22.1
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# label
# 0    4825
# 1     747
# Name: count, dtype: int64
# label
# 0    4825
# 1     747
# Name: count, dtype: int64
# label
# 1    747
# 0    747
# Name: count, dtype: int64
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# 2026-02-08 08:24:59.349937: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770539099.529939      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770539099.583772      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770539100.017907      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770539100.017942      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770539100.017945      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770539100.017948      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Testing configuration 1: {'learning_rate': 1e-05, 'epochs': 7, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.2529 | Train Accuracy: 0.9094
# Validation Loss: 0.1823 | Validation Accuracy: 0.9440
# Time: 64.98 seconds
# New best model saved with accuracy: 0.9440
# Epoch 2 | Train Loss: 0.1109 | Train Accuracy: 0.9674
# Validation Loss: 0.1443 | Validation Accuracy: 0.9549
# Time: 65.90 seconds
# New best model saved with accuracy: 0.9549
# Epoch 3 | Train Loss: 0.0715 | Train Accuracy: 0.9812
# Validation Loss: 0.1457 | Validation Accuracy: 0.9620
# Time: 68.77 seconds
# New best model saved with accuracy: 0.9620
# Epoch 4 | Train Loss: 0.0496 | Train Accuracy: 0.9900
# Validation Loss: 0.1502 | Validation Accuracy: 0.9620
# Time: 68.68 seconds
# Epoch 5 | Train Loss: 0.0379 | Train Accuracy: 0.9929
# Validation Loss: 0.1482 | Validation Accuracy: 0.9631
# Time: 68.67 seconds
# New best model saved with accuracy: 0.9631
# Epoch 6 | Train Loss: 0.0357 | Train Accuracy: 0.9929
# Validation Loss: 0.1486 | Validation Accuracy: 0.9595
# Time: 68.68 seconds
# Epoch 7 | Train Loss: 0.0300 | Train Accuracy: 0.9949
# Validation Loss: 0.1514 | Validation Accuracy: 0.9604
# Time: 68.86 seconds
# Testing configuration 2: {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32}
# Epoch 1 | Train Loss: 0.0354 | Train Accuracy: 0.9920
# Validation Loss: 0.1674 | Validation Accuracy: 0.9648
# Time: 68.88 seconds
# New best model saved with accuracy: 0.9648
# Epoch 2 | Train Loss: 0.0260 | Train Accuracy: 0.9935
# Validation Loss: 0.1725 | Validation Accuracy: 0.9641
# Time: 68.75 seconds
# Epoch 3 | Train Loss: 0.0206 | Train Accuracy: 0.9953
# Validation Loss: 0.1698 | Validation Accuracy: 0.9632
# Time: 68.72 seconds
# Epoch 4 | Train Loss: 0.0177 | Train Accuracy: 0.9964
# Validation Loss: 0.1840 | Validation Accuracy: 0.9623
# Time: 68.84 seconds
# Epoch 5 | Train Loss: 0.0152 | Train Accuracy: 0.9973
# Validation Loss: 0.1716 | Validation Accuracy: 0.9641
# Time: 68.91 seconds
# Testing configuration 3: {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.0198 | Train Accuracy: 0.9964
# Validation Loss: 0.1725 | Validation Accuracy: 0.9659
# Time: 68.77 seconds
# New best model saved with accuracy: 0.9659
# Epoch 2 | Train Loss: 0.0139 | Train Accuracy: 0.9962
# Validation Loss: 0.1825 | Validation Accuracy: 0.9641
# Time: 68.81 seconds
# Epoch 3 | Train Loss: 0.0123 | Train Accuracy: 0.9975
# Validation Loss: 0.1813 | Validation Accuracy: 0.9631
# Time: 68.80 seconds
# Testing configuration 4: {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 32}
# Epoch 1 | Train Loss: 0.0312 | Train Accuracy: 0.9917
# Validation Loss: 0.1624 | Validation Accuracy: 0.9577
# Time: 69.03 seconds
# Epoch 2 | Train Loss: 0.0154 | Train Accuracy: 0.9969
# Validation Loss: 0.1748 | Validation Accuracy: 0.9686
# Time: 68.89 seconds
# New best model saved with accuracy: 0.9686
# Epoch 3 | Train Loss: 0.0100 | Train Accuracy: 0.9973
# Validation Loss: 0.1947 | Validation Accuracy: 0.9650
# Time: 68.71 seconds
# Epoch 4 | Train Loss: 0.0057 | Train Accuracy: 0.9989
# Validation Loss: 0.1947 | Validation Accuracy: 0.9623
# Time: 68.64 seconds
# Epoch 5 | Train Loss: 0.0031 | Train Accuracy: 0.9996
# Validation Loss: 0.2002 | Validation Accuracy: 0.9623
# Time: 68.87 seconds
# Testing configuration 5: {'learning_rate': 5e-05, 'epochs': 7, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.0234 | Train Accuracy: 0.9929
# Validation Loss: 0.2176 | Validation Accuracy: 0.9597
# Time: 69.29 seconds
# Epoch 2 | Train Loss: 0.0168 | Train Accuracy: 0.9960
# Validation Loss: 0.2472 | Validation Accuracy: 0.9372
# Time: 69.21 seconds
# Epoch 3 | Train Loss: 0.0091 | Train Accuracy: 0.9980
# Validation Loss: 0.2124 | Validation Accuracy: 0.9588
# Time: 69.30 seconds
# Epoch 4 | Train Loss: 0.0065 | Train Accuracy: 0.9984
# Validation Loss: 0.1996 | Validation Accuracy: 0.9650
# Time: 68.99 seconds
# Epoch 5 | Train Loss: 0.0022 | Train Accuracy: 0.9998
# Validation Loss: 0.1881 | Validation Accuracy: 0.9632
# Time: 68.70 seconds
# Epoch 6 | Train Loss: 0.0025 | Train Accuracy: 0.9996
# Validation Loss: 0.2042 | Validation Accuracy: 0.9605
# Time: 68.69 seconds
# Epoch 7 | Train Loss: 0.0010 | Train Accuracy: 0.9998
# Validation Loss: 0.2058 | Validation Accuracy: 0.9605
# Time: 68.63 seconds
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       939
#            1       0.92      0.82      0.87       176
#
#     accuracy                           0.96      1115
#    macro avg       0.94      0.90      0.92      1115
# weighted avg       0.96      0.96      0.96      1115
#
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0009 | Train Accuracy: 0.9998
# Validation Loss: 0.2058 | Validation Accuracy: 0.9605
# Time: 66.17 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0009 | Train Accuracy: 0.9998
# Validation Loss: 0.2058 | Validation Accuracy: 0.9605
# Time: 66.21 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0010 | Train Accuracy: 0.9998
# Validation Loss: 0.2059 | Validation Accuracy: 0.9605
# Time: 66.28 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0010 | Train Accuracy: 0.9998
# Validation Loss: 0.2060 | Validation Accuracy: 0.9605
# Time: 66.58 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0009 | Train Accuracy: 0.9998
# Validation Loss: 0.2060 | Validation Accuracy: 0.9605
# Time: 66.97 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0147 | Train Accuracy: 0.9959
# Validation Loss: 0.2070 | Validation Accuracy: 0.9614
# Time: 69.27 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0138 | Train Accuracy: 0.9958
# Validation Loss: 0.2036 | Validation Accuracy: 0.9677
# Time: 68.79 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0016 | Train Accuracy: 0.9993
# Validation Loss: 0.2140 | Validation Accuracy: 0.9668
# Time: 68.73 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0009 | Train Accuracy: 0.9998
# Validation Loss: 0.1772 | Validation Accuracy: 0.9668
# Time: 68.64 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0004 | Train Accuracy: 1.0000
# Validation Loss: 0.1783 | Validation Accuracy: 0.9668
# Time: 68.73 seconds
# --------------------------------------------------
# Optimizer: rmsprop | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 1
# Train Loss: 0.0781 | Train Accuracy: 0.9747
# Validation Loss: 0.1438 | Validation Accuracy: 0.9643
# Time: 68.12 seconds
# --------------------------------------------------
# Optimizer: rmsprop | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 2
# Train Loss: 0.0115 | Train Accuracy: 0.9980
# Validation Loss: 0.1878 | Validation Accuracy: 0.9670
# Time: 68.02 seconds
# --------------------------------------------------
# Optimizer: rmsprop | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 3
# Train Loss: 0.0062 | Train Accuracy: 0.9987
# Validation Loss: 0.1835 | Validation Accuracy: 0.9679
# Time: 67.86 seconds
# --------------------------------------------------
# Optimizer: rmsprop | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 4
# Train Loss: 0.0047 | Train Accuracy: 0.9991
# Validation Loss: 0.1926 | Validation Accuracy: 0.9652
# Time: 68.04 seconds
# --------------------------------------------------
# Optimizer: rmsprop | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 5
# Train Loss: 0.0006 | Train Accuracy: 1.0000
# Validation Loss: 0.2069 | Validation Accuracy: 0.9679
# Time: 68.09 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 2e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0003 | Train Accuracy: 1.0000
# Validation Loss: 0.2078 | Validation Accuracy: 0.9677
# Time: 66.31 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 2e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0003 | Train Accuracy: 1.0000
# Validation Loss: 0.2078 | Validation Accuracy: 0.9677
# Time: 66.37 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 2e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0003 | Train Accuracy: 1.0000
# Validation Loss: 0.2078 | Validation Accuracy: 0.9677
# Time: 66.39 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 2e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0003 | Train Accuracy: 1.0000
# Validation Loss: 0.2078 | Validation Accuracy: 0.9677
# Time: 66.33 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 2e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0005 | Train Accuracy: 0.9998
# Validation Loss: 0.2078 | Validation Accuracy: 0.9677
# Time: 66.19 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 1
# Train Loss: 0.0073 | Train Accuracy: 0.9989
# Validation Loss: 0.3109 | Validation Accuracy: 0.9643
# Time: 69.40 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 2
# Train Loss: 0.0004 | Train Accuracy: 1.0000
# Validation Loss: 0.2988 | Validation Accuracy: 0.9643
# Time: 69.32 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 3
# Train Loss: 0.0083 | Train Accuracy: 0.9984
# Validation Loss: 0.2314 | Validation Accuracy: 0.9652
# Time: 69.25 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 4
# Train Loss: 0.0002 | Train Accuracy: 1.0000
# Validation Loss: 0.2472 | Validation Accuracy: 0.9661
# Time: 69.19 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 5
# Train Loss: 0.0002 | Train Accuracy: 1.0000
# Validation Loss: 0.2473 | Validation Accuracy: 0.9661
# Time: 69.25 seconds
# --------------------------------------------------
# Best Validation Accuracy: 0.9679
# Best Parameters: Optimizer = rmsprop, Learning Rate = 5e-05, Batch Size = 16

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix,
    classification_report, roc_curve
)
import matplotlib.pyplot as plt
import numpy as np
import torch

def evaluate_binary_model(model, dataloader, device):
    model.eval()
    all_true_labels = []
    all_probs = []

    with torch.no_grad():
        for batch in dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            outputs = model(b_input_ids, b_input_mask)
            probs = torch.softmax(outputs, dim=1)

            all_true_labels.append(b_labels.cpu().numpy())
            all_probs.append(probs.cpu().numpy())

    # Convert to numpy
    all_true_labels = np.concatenate(all_true_labels)
    all_probs = np.concatenate(all_probs)
    all_preds = np.argmax(all_probs, axis=1)

    # ================= Metrics =================
    tn, fp, fn, tp = confusion_matrix(all_true_labels, all_preds).ravel()

    accuracy = accuracy_score(all_true_labels, all_preds)
    precision = precision_score(all_true_labels, all_preds)
    recall = recall_score(all_true_labels, all_preds)          # Sensitivity
    specificity = tn / (tn + fp)
    f1 = f1_score(all_true_labels, all_preds)
    auc = roc_auc_score(all_true_labels, all_probs[:, 1])

    # ================= Print metrics =================
    print("===== Evaluation Metrics =====")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"Sensitivity : {recall:.4f}")
    print(f"Specificity : {specificity:.4f}")
    print(f"F1-score    : {f1:.4f}")
    print(f"AUC         : {auc:.4f}")

    # ================= Classification Report =================
    print("\n===== Classification Report =====")
    print(classification_report(all_true_labels, all_preds, digits=4))

    # ================= ROC Curve (Both Classes) =================
    fpr_0, tpr_0, _ = roc_curve(all_true_labels, all_probs[:, 0], pos_label=0)
    fpr_1, tpr_1, _ = roc_curve(all_true_labels, all_probs[:, 1], pos_label=1)

    auc_0 = roc_auc_score(1 - all_true_labels, all_probs[:, 0])
    auc_1 = roc_auc_score(all_true_labels, all_probs[:, 1])

    plt.figure(figsize=(7, 6))
    plt.plot(fpr_0, tpr_0, label=f"Class 0 ROC (AUC = {auc_0:.2f})", lw=2)
    plt.plot(fpr_1, tpr_1, label=f"Class 1 ROC (AUC = {auc_1:.2f})", lw=2)
    plt.plot([0, 1], [0, 1], 'k--', lw=2)

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve for Binary Classification")
    plt.legend(loc="lower right")
    plt.grid()
    plt.tight_layout()
    plt.show()

    return accuracy, precision, recall, specificity, f1, auc


accuracy, precision, recall, specificity, f1, auc = evaluate_binary_model(
    model, val_dataloader, device
)
# Out:
# ===== Evaluation Metrics =====
# Accuracy     : 0.9659
# Precision    : 0.9662
# Recall       : 0.8125
# Sensitivity : 0.8125
# Specificity : 0.9947
# F1-score    : 0.8827
# AUC         : 0.9779
#
# ===== Classification Report =====
#               precision    recall  f1-score   support
#
#            0     0.9659    0.9947    0.9801       939
#            1     0.9662    0.8125    0.8827       176
#
#     accuracy                         0.9659      1115
#    macro avg     0.9660    0.9036    0.9314      1115
# weighted avg     0.9659    0.9659    0.9647      1115

# %%
import re, time, random, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
from transformers import AutoTokenizer, AutoModel
from torch.optim import AdamW

import nltk
from nltk.corpus import stopwords

warnings.filterwarnings("ignore")
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))


df = pd.read_csv("/kaggle/input/spam-dataset-qtl/spamdata_v2 (1).csv")

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    words = [w for w in text.split() if w not in stop_words]
    return " ".join(words)

df["cleaned_text"] = df["text"].astype(str).apply(clean_text)

le = LabelEncoder()
df["label"] = le.fit_transform(df["label"])
min_class = df["label"].value_counts().min()

df_balanced = (
    df.groupby("label", group_keys=False)
      .apply(lambda x: x.sample(min_class, random_state=42))
      .sample(frac=1, random_state=42)
)

print(df_balanced["label"].value_counts())
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

tokens = tokenizer(
    df_balanced["cleaned_text"].tolist(),
    padding="max_length",
    truncation=True,
    max_length=128,
    return_tensors="pt"
)

input_ids = tokens["input_ids"]
attention_mask = tokens["attention_mask"]
labels = torch.tensor(df_balanced["label"].values)
X_train, X_val, y_train, y_val, m_train, m_val = train_test_split(
    input_ids, labels, attention_mask, test_size=0.2, random_state=42
)

train_data = TensorDataset(X_train, m_train, y_train)
val_data = TensorDataset(X_val, m_val, y_val)

train_loader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=16)
val_loader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=16)
dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev, interface="torch")
def qc1(weights, x):
    qml.Hadamard(0)
    qml.Hadamard(1)
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([0,1])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc2(weights, x):
    qml.Hadamard(0)
    qml.RY(x[0], 0)
    qml.RX(x[1], 1)
    qml.CNOT([1,0])
    qml.RX(weights[0], 0)
    qml.RY(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc3(weights, x):
    for i in range(2):
        qml.Hadamard(i)
        qml.RX(x[i], i)
        qml.RY(weights[i], i)
        qml.RZ(weights[i], i)
    qml.CNOT([0,1])
    return qml.expval(qml.PauliZ(1))

@qml.qnode(dev, interface="torch")
def qc4(weights, x):
    qml.Hadamard(0)
    qml.CNOT([0,1])
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([1,0])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

QUANTUM_CIRCUITS = {
    "QC1": qc1,
    "QC2": qc2,
    "QC3": qc3,
    "QC4": qc4
}
class QBiLSTM(nn.Module):
    def __init__(self, quantum_circuit):
        super().__init__()
        self.qc = quantum_circuit
        self.q_weights = nn.Parameter(torch.randn(2))

        self.encoder = AutoModel.from_pretrained("distilbert-base-uncased")

        self.bilstm = nn.LSTM(
            input_size=768,
            hidden_size=128,
            bidirectional=True,
            batch_first=True
        )

        self.fc = nn.Linear(256, 2)

    def quantum_layer(self, x):
        q_outs = []
        for v in x:
            q_outs.append(self.qc(self.q_weights, v[:2]))
        return torch.stack(q_outs)

    def forward(self, input_ids, attention_mask):
        enc = self.encoder(input_ids, attention_mask).last_hidden_state
        lstm_out, _ = self.bilstm(enc)
        h = lstm_out[:, -1, :]

        _ = self.quantum_layer(h)  # quantum interaction

        return self.fc(h)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
results = {}

for name, qc in QUANTUM_CIRCUITS.items():
    print(f"\n====== Training {name} ======")

    model = QBiLSTM(qc).to(device)
    optimizer = AdamW(model.parameters(), lr=2e-5)
    loss_fn = nn.CrossEntropyLoss()

    for epoch in range(10):
        print(f"\n--- Epoch {epoch+1}/10 ---")
        model.train()
        total_loss = 0

        for step, batch in enumerate(train_loader, 1):
            ids, mask, y = [b.to(device) for b in batch]

            optimizer.zero_grad()
            out = model(ids, mask)
            loss = loss_fn(out, y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            if step % 50 == 0:  # print every 50 steps
                print(f"Step {step}: Loss = {loss.item():.4f}")

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1} finished. Avg Loss = {avg_loss:.4f}")

    # Evaluation
    model.eval()
    preds, gold = [], []
    with torch.no_grad():
        for batch in val_loader:
            ids, mask, y = [b.to(device) for b in batch]
            logits = model(ids, mask)
            preds.extend(torch.argmax(logits, 1).cpu().numpy())
            gold.extend(y.cpu().numpy())

    acc = accuracy_score(gold, preds)
    results[name] = acc

    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(gold, preds))

print("\n===== FINAL QUANTUM CIRCUIT COMPARISON =====")
for k, v in results.items():
    print(f"{k}: {v:.4f}")
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# label
# 1    747
# 0    747
# Name: count, dtype: int64
#
# ====== Training QC1 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.0728
# Epoch 1 finished. Avg Loss = 0.2939
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.0332
# Epoch 2 finished. Avg Loss = 0.1225
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.1748
# Epoch 3 finished. Avg Loss = 0.0704
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0115
# Epoch 4 finished. Avg Loss = 0.0321
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0069
# Epoch 5 finished. Avg Loss = 0.0157
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0050
# Epoch 6 finished. Avg Loss = 0.0103
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0034
# Epoch 7 finished. Avg Loss = 0.0065
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0023
# Epoch 8 finished. Avg Loss = 0.0037
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0021
# Epoch 9 finished. Avg Loss = 0.0028
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0017
# Epoch 10 finished. Avg Loss = 0.0020
# QC1 Accuracy: 0.9532
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       155
#            1       0.95      0.96      0.95       144
#
#     accuracy                           0.95       299
#    macro avg       0.95      0.95      0.95       299
# weighted avg       0.95      0.95      0.95       299
#
#
# ====== Training QC2 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.6156
# Epoch 1 finished. Avg Loss = 0.3038
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.1674
# Epoch 2 finished. Avg Loss = 0.1284
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.0168
# Epoch 3 finished. Avg Loss = 0.0706
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0243
# Epoch 4 finished. Avg Loss = 0.0400
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0087
# Epoch 5 finished. Avg Loss = 0.0250
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0049
# Epoch 6 finished. Avg Loss = 0.0189
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0041
# Epoch 7 finished. Avg Loss = 0.0129
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0173
# Epoch 8 finished. Avg Loss = 0.0197
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0030
# Epoch 9 finished. Avg Loss = 0.0099
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0019
# Epoch 10 finished. Avg Loss = 0.0088
# QC2 Accuracy: 0.9365
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       155
#            1       1.00      0.87      0.93       144
#
#     accuracy                           0.94       299
#    macro avg       0.95      0.93      0.94       299
# weighted avg       0.94      0.94      0.94       299
#
#
# ====== Training QC3 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.3550
# Epoch 1 finished. Avg Loss = 0.3310
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.0741
# Epoch 2 finished. Avg Loss = 0.1352
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.1890
# Epoch 3 finished. Avg Loss = 0.0850
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0160
# Epoch 4 finished. Avg Loss = 0.0586
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0141
# Epoch 5 finished. Avg Loss = 0.0444
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0130
# Epoch 6 finished. Avg Loss = 0.0330
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0975
# Epoch 7 finished. Avg Loss = 0.0154
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0045
# Epoch 8 finished. Avg Loss = 0.0082
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0027
# Epoch 9 finished. Avg Loss = 0.0038
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0021
# Epoch 10 finished. Avg Loss = 0.0029
# QC3 Accuracy: 0.9565
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       155
#            1       0.94      0.97      0.96       144
#
#     accuracy                           0.96       299
#    macro avg       0.96      0.96      0.96       299
# weighted avg       0.96      0.96      0.96       299
#
#
# ====== Training QC4 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.2285
# Epoch 1 finished. Avg Loss = 0.3131
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.0923
# Epoch 2 finished. Avg Loss = 0.1186
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.0282
# Epoch 3 finished. Avg Loss = 0.0610
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0104
# Epoch 4 finished. Avg Loss = 0.0328
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0074
# Epoch 5 finished. Avg Loss = 0.0209
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0046
# Epoch 6 finished. Avg Loss = 0.0116
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0278
# Epoch 7 finished. Avg Loss = 0.0639
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0051
# Epoch 8 finished. Avg Loss = 0.0093
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0043
# Epoch 9 finished. Avg Loss = 0.0056
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0024
# Epoch 10 finished. Avg Loss = 0.0027
# QC4 Accuracy: 0.9632
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       155
#            1       0.95      0.97      0.96       144
#
#     accuracy                           0.96       299
#    macro avg       0.96      0.96      0.96       299
# weighted avg       0.96      0.96      0.96       299
#
#
# ===== FINAL QUANTUM CIRCUIT COMPARISON =====
# QC1: 0.9532
# QC2: 0.9365
# QC3: 0.9565
# QC4: 0.9632

# %% [markdown]
# # **DeBERTa-v3-base**

# %%
# !pip install pennylane
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import transformers
from transformers import AutoModel, BertTokenizerFast
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
from sklearn.metrics import (
    roc_curve, roc_auc_score, classification_report, confusion_matrix
)
from sklearn.preprocessing import label_binarize
import pennylane as qml
from pennylane import numpy as pnp
import re
import warnings
import re
import nltk
from nltk.corpus import stopwords
warnings.filterwarnings('ignore')
# Label encoding for 'status' column
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoModel
import pennylane as qml
# Convert data to PyTorch DataLoader format
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
import time
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc
from transformers import get_linear_schedule_with_warmup
from torch.optim import AdamW
from sklearn.model_selection import ParameterSampler
import random
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import torch
from sklearn.preprocessing import label_binarize
import time
import random
import numpy as np
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import get_linear_schedule_with_warmup
from transformers import AutoTokenizer, AutoModel

df = pd.read_csv("/kaggle/input/spam-dataset-qtl/spamdata_v2 (1).csv")
df.head()

df.shape


def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)  # Remove links
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    text = re.sub(r'#\w+', '', text)  # Remove hashtags
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = text.lower()  # Convert to lowercase
    return text

df['cleaned_text'] = df['text'].apply(preprocess_text)

df = df[df['cleaned_text'] != '[deleted]']
df = df[df['cleaned_text'] != '[removed]']

df.head()

# Download NLTK stopwords (only needed once)
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

def clean_statement(statement):
    # Convert to lowercase
    statement = statement.lower()

    # Remove special characters (punctuation, non-alphabetic characters)
    statement = re.sub(r'[^\w\s]', '', statement)

    # Remove numbers (optional, depending on your use case)
    statement = re.sub(r'\d+', '', statement)

    # Tokenize the statement (split into words)
    words = statement.split()

    # Remove stopwords
    words = [word for word in words if word not in stop_words]

    # Rejoin words into a cleaned statement
    cleaned_statement = ' '.join(words)

    return cleaned_statement

# Apply the cleaning function to the 'statement' column
df['cleaned_text'] = df['cleaned_text'].apply(clean_statement)

df


label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])

df.head()

# Check the number of samples per class
class_counts = df['label'].value_counts()
print(class_counts)
# Separate majority and minority classes
class_counts = df['label'].value_counts()
print(class_counts)

majority_class = df['label'].value_counts().idxmax()
minority_class = df['label'].value_counts().idxmin()

df_majority = df[df['label'] == majority_class]
df_minority = df[df['label'] == minority_class]

# Downsample majority to match minority
df_majority_downsampled = df_majority.sample(len(df_minority), random_state=42)

# Combine
df_balanced = pd.concat([df_majority_downsampled, df_minority])

# Shuffle
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

print(df_balanced['label'].value_counts())


class_counts.plot(kind='bar', title='Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.show()

# Initialize the tokenizer and model from Hugging Face
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-base")

tokens = tokenizer.batch_encode_plus(
    df['cleaned_text'].tolist(),
    max_length=128,
    padding="max_length",   # <-- updated
    truncation=True,
    return_tensors="pt"
)

# Convert to tensors
input_ids = torch.tensor(tokens['input_ids'])
attention_masks = torch.tensor(tokens['attention_mask'])
labels = torch.tensor(df['label'].values)

# Split the data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(input_ids, labels, test_size=0.2)
train_masks, val_masks, _, _ = train_test_split(attention_masks, input_ids, test_size=0.2)


train_data = TensorDataset(train_inputs, train_masks, train_labels)
val_data = TensorDataset(val_inputs, val_masks, val_labels)

train_dataloader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=32)
val_dataloader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=32)

# Create a quantum node (circuit)
dev = qml.device("default.qubit", wires=2)  # or 'default.qubit'

@qml.qnode(dev)
def quantum_circuit(weights, inputs):
    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RX(inputs[0], wires=0)
    qml.RY(inputs[1], wires=1)

    qml.CNOT(wires=[0, 1])

    qml.RZ(weights[0], wires=0)
    qml.RZ(weights[1], wires=1)

    return qml.expval(qml.PauliZ(0))

class QBiLSTM(nn.Module):
    def __init__(self):
        super(QBiLSTM, self).__init__()

        self.bert = AutoModel.from_pretrained("microsoft/deberta-v3-base")

        # 🔁 BiLSTM instead of LSTM
        self.bilstm = nn.LSTM(
            input_size=768,
            hidden_size=128,
            batch_first=True,
            bidirectional=True
        )

        # 128 × 2 because BiLSTM
        self.fc = nn.Linear(256, 2)

    def quantum_layer(self, inputs):
        processed_features = []

        for feature_vector in inputs:
            features_for_quantum = feature_vector[:2]
            q_out = quantum_circuit(
                torch.randn(2, dtype=torch.float32),
                features_for_quantum
            )
            processed_features.append(q_out)

        return torch.stack(processed_features).unsqueeze(1)

    def forward(self, input_ids, attention_mask):
        bert_output = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # BiLSTM output
        lstm_output, _ = self.bilstm(bert_output.last_hidden_state)

        # Last timestep (batch, 256)
        last_hidden = lstm_output[:, -1, :]

        _ = self.quantum_layer(last_hidden)

        # Classification
        output = self.fc(last_hidden)
        return output


model = QBiLSTM()

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define hyperparameter search space
param_grid = {
    'learning_rate': [1e-5, 2e-5, 3e-5, 5e-5],
    'batch_size': [16, 32],
    'epochs': [3, 5, 7]
}

num_samples = 5  
param_list = list(ParameterSampler(param_grid, n_iter=num_samples, random_state=42))

best_model = None
best_val_accuracy = 0.0
best_params = None

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# Loop through each random set of hyperparameters
for idx, params in enumerate(param_list):
    print(f"Testing configuration {idx + 1}: {params}")

    learning_rate = params['learning_rate']
    batch_size = params['batch_size']
    epochs = params['epochs']

    # Define optimizer and scheduler
    optimizer = AdamW(model.parameters(), lr=learning_rate)
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

    for epoch in range(epochs):
        start_time = time.time()
        model.train()
        total_train_loss = 0
        total_train_accuracy = 0

        for batch in train_dataloader:
            b_input_ids, b_input_mask, b_labels = batch

            # Move tensors to the same device
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            optimizer.zero_grad()
            outputs = model(b_input_ids, b_input_mask)
            loss = nn.CrossEntropyLoss()(outputs, b_labels)
            total_train_loss += loss.item()

            logits = outputs.detach().cpu().numpy()
            label_ids = b_labels.cpu().numpy()
            total_train_accuracy += flat_accuracy(logits, label_ids)

            loss.backward()
            optimizer.step()
            scheduler.step()

        avg_train_loss = total_train_loss / len(train_dataloader)
        avg_train_accuracy = total_train_accuracy / len(train_dataloader)

        # Validation
        model.eval()
        total_val_loss = 0
        total_val_accuracy = 0
        all_preds = []
        all_labels = []

        for batch in val_dataloader:
            b_input_ids, b_input_mask, b_labels = batch

            # Move tensors to the same device
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            with torch.no_grad():
                outputs = model(b_input_ids, b_input_mask)
                loss = nn.CrossEntropyLoss()(outputs, b_labels)
                total_val_loss += loss.item()

                logits = outputs.detach().cpu().numpy()
                label_ids = b_labels.cpu().numpy()
                total_val_accuracy += flat_accuracy(logits, label_ids)

                all_preds.extend(np.argmax(logits, axis=1).flatten())
                all_labels.extend(label_ids.flatten())

        avg_val_loss = total_val_loss / len(val_dataloader)
        avg_val_accuracy = total_val_accuracy / len(val_dataloader)
        elapsed_time = time.time() - start_time

        print(f"Epoch {epoch+1} | Train Loss: {avg_train_loss:.4f} | Train Accuracy: {avg_train_accuracy:.4f}")
        print(f"Validation Loss: {avg_val_loss:.4f} | Validation Accuracy: {avg_val_accuracy:.4f}")
        print(f"Time: {elapsed_time:.2f} seconds")

        # Save best model
        if avg_val_accuracy > best_val_accuracy:
            best_val_accuracy = avg_val_accuracy
            best_model = model.state_dict()
            best_params = params
            torch.save(best_model, 'best_model.pth')
            print(f"New best model saved with accuracy: {best_val_accuracy:.4f}")

# Generate classification report
print("Classification Report:")
print(classification_report(all_labels, all_preds))



# Define search space for hyperparameters
epochs = 5
learning_rates = [2e-5, 3e-5, 5e-5]
batch_sizes = [16, 32]
optimizers = ['adamw', 'adam', 'rmsprop', 'sgd']

# Number of random samples to try
num_samples = 5

# Function to calculate accuracy
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# Function to get optimizer
def get_optimizer(optimizer_name, model_parameters, lr):
    if optimizer_name == 'adamw':
        return optim.AdamW(model_parameters, lr=lr)
    elif optimizer_name == 'adam':
        return optim.Adam(model_parameters, lr=lr)
    elif optimizer_name == 'rmsprop':
        return optim.RMSprop(model_parameters, lr=lr)
    elif optimizer_name == 'sgd':
        return optim.SGD(model_parameters, lr=lr)

# Randomly sample hyperparameter combinations
random_hyperparams = [
    {
        "optimizer": random.choice(optimizers),
        "learning_rate": random.choice(learning_rates),
        "batch_size": random.choice(batch_sizes),
    }
    for _ in range(num_samples)
]

best_accuracy = 0
best_params = {}

# Iterate over randomly chosen hyperparameter sets
for params in random_hyperparams:
    optimizer_name = params["optimizer"]
    lr = params["learning_rate"]
    batch_size = params["batch_size"]

    # Initialize data loaders
    train_dataloader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=batch_size)
    val_dataloader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=batch_size)

    # Define optimizer and scheduler
    optimizer = get_optimizer(optimizer_name, model.parameters(), lr)
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

    # Move model to device
    model.to(device)

    for epoch in range(epochs):
        start_time = time.time()

        # Training
        model.train()
        total_train_loss = 0
        total_train_accuracy = 0
        for batch in train_dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids, b_input_mask, b_labels = b_input_ids.to(device), b_input_mask.to(device), b_labels.to(device)

            optimizer.zero_grad()
            outputs = model(b_input_ids, b_input_mask)
            loss = nn.CrossEntropyLoss()(outputs, b_labels)
            total_train_loss += loss.item()

            logits = outputs.detach().cpu().numpy()
            label_ids = b_labels.cpu().numpy()
            total_train_accuracy += flat_accuracy(logits, label_ids)

            loss.backward()
            optimizer.step()
            scheduler.step()

        avg_train_loss = total_train_loss / len(train_dataloader)
        avg_train_accuracy = total_train_accuracy / len(train_dataloader)

        # Validation
        model.eval()
        total_val_loss = 0
        total_val_accuracy = 0
        for batch in val_dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids, b_input_mask, b_labels = b_input_ids.to(device), b_input_mask.to(device), b_labels.to(device)

            with torch.no_grad():
                outputs = model(b_input_ids, b_input_mask)
                loss = nn.CrossEntropyLoss()(outputs, b_labels)
                total_val_loss += loss.item()

                logits = outputs.detach().cpu().numpy()
                label_ids = b_labels.cpu().numpy()
                total_val_accuracy += flat_accuracy(logits, label_ids)

        avg_val_loss = total_val_loss / len(val_dataloader)
        avg_val_accuracy = total_val_accuracy / len(val_dataloader)

        elapsed_time = time.time() - start_time

        print(f"Optimizer: {optimizer_name} | Learning Rate: {lr} | Batch Size: {batch_size}")
        print(f"Epoch {epoch+1}")
        print(f"Train Loss: {avg_train_loss:.4f} | Train Accuracy: {avg_train_accuracy:.4f}")
        print(f"Validation Loss: {avg_val_loss:.4f} | Validation Accuracy: {avg_val_accuracy:.4f}")
        print(f"Time: {elapsed_time:.2f} seconds")
        print("-" * 50)

        # Update best parameters if validation accuracy improves
        if avg_val_accuracy > best_accuracy:
            best_accuracy = avg_val_accuracy
            best_params = {"optimizer": optimizer_name, "learning_rate": lr, "batch_size": batch_size}

print(f"Best Validation Accuracy: {best_accuracy:.4f}")
print(f"Best Parameters: Optimizer = {best_params['optimizer']}, Learning Rate = {best_params['learning_rate']}, Batch Size = {best_params['batch_size']}")
# Out:
# Collecting pennylane
#   Downloading pennylane-0.44.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane)
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.44 (from pennylane)
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.0rc2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane)
#   Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.44.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 57.5 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 55.2 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 86.8 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.8 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 13.6 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 102.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 pennylane-0.44.0 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.22.1
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# label
# 0    4825
# 1     747
# Name: count, dtype: int64
# label
# 0    4825
# 1     747
# Name: count, dtype: int64
# label
# 1    747
# 0    747
# Name: count, dtype: int64
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# 2026-02-08 04:52:36.273329: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770526356.467406      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770526356.518247      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770526356.979018      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770526356.979066      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770526356.979069      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770526356.979071      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Testing configuration 1: {'learning_rate': 1e-05, 'epochs': 7, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.3548 | Train Accuracy: 0.8691
# Validation Loss: 0.3213 | Validation Accuracy: 0.8012
# Time: 150.86 seconds
# New best model saved with accuracy: 0.8012
# Epoch 2 | Train Loss: 0.2497 | Train Accuracy: 0.9172
# Validation Loss: 0.2040 | Validation Accuracy: 0.9222
# Time: 160.60 seconds
# New best model saved with accuracy: 0.9222
# Epoch 3 | Train Loss: 0.1646 | Train Accuracy: 0.9475
# Validation Loss: 0.1884 | Validation Accuracy: 0.9282
# Time: 161.29 seconds
# New best model saved with accuracy: 0.9282
# Epoch 4 | Train Loss: 0.1412 | Train Accuracy: 0.9513
# Validation Loss: 0.1556 | Validation Accuracy: 0.9420
# Time: 161.34 seconds
# New best model saved with accuracy: 0.9420
# Epoch 5 | Train Loss: 0.1235 | Train Accuracy: 0.9600
# Validation Loss: 0.1500 | Validation Accuracy: 0.9518
# Time: 161.39 seconds
# New best model saved with accuracy: 0.9518
# Epoch 6 | Train Loss: 0.1033 | Train Accuracy: 0.9693
# Validation Loss: 0.1435 | Validation Accuracy: 0.9446
# Time: 161.75 seconds
# Epoch 7 | Train Loss: 0.0932 | Train Accuracy: 0.9750
# Validation Loss: 0.1413 | Validation Accuracy: 0.9518
# Time: 161.50 seconds
# Testing configuration 2: {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32}
# Epoch 1 | Train Loss: 0.1189 | Train Accuracy: 0.9629
# Validation Loss: 0.1322 | Validation Accuracy: 0.9571
# Time: 161.32 seconds
# New best model saved with accuracy: 0.9571
# Epoch 2 | Train Loss: 0.0980 | Train Accuracy: 0.9699
# Validation Loss: 0.1484 | Validation Accuracy: 0.9470
# Time: 161.42 seconds
# Epoch 3 | Train Loss: 0.0793 | Train Accuracy: 0.9775
# Validation Loss: 0.1324 | Validation Accuracy: 0.9543
# Time: 161.16 seconds
# Epoch 4 | Train Loss: 0.0715 | Train Accuracy: 0.9805
# Validation Loss: 0.1279 | Validation Accuracy: 0.9616
# Time: 161.27 seconds
# New best model saved with accuracy: 0.9616
# Epoch 5 | Train Loss: 0.0597 | Train Accuracy: 0.9839
# Validation Loss: 0.1261 | Validation Accuracy: 0.9616
# Time: 161.24 seconds
# Testing configuration 3: {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.0813 | Train Accuracy: 0.9770
# Validation Loss: 0.1328 | Validation Accuracy: 0.9607
# Time: 161.03 seconds
# Epoch 2 | Train Loss: 0.0590 | Train Accuracy: 0.9844
# Validation Loss: 0.1370 | Validation Accuracy: 0.9643
# Time: 160.83 seconds
# New best model saved with accuracy: 0.9643
# Epoch 3 | Train Loss: 0.0489 | Train Accuracy: 0.9879
# Validation Loss: 0.1449 | Validation Accuracy: 0.9598
# Time: 160.72 seconds
# Testing configuration 4: {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 32}
# Epoch 1 | Train Loss: 0.1398 | Train Accuracy: 0.9598
# Validation Loss: 0.1677 | Validation Accuracy: 0.9479
# Time: 160.71 seconds
# Epoch 2 | Train Loss: 0.1013 | Train Accuracy: 0.9719
# Validation Loss: 0.1770 | Validation Accuracy: 0.9563
# Time: 161.00 seconds
# Epoch 3 | Train Loss: 0.0694 | Train Accuracy: 0.9806
# Validation Loss: 0.1747 | Validation Accuracy: 0.9390
# Time: 160.87 seconds
# Epoch 4 | Train Loss: 0.0555 | Train Accuracy: 0.9846
# Validation Loss: 0.1127 | Validation Accuracy: 0.9723
# Time: 161.06 seconds
# New best model saved with accuracy: 0.9723
# Epoch 5 | Train Loss: 0.0349 | Train Accuracy: 0.9917
# Validation Loss: 0.1233 | Validation Accuracy: 0.9652
# Time: 160.91 seconds
# Testing configuration 5: {'learning_rate': 5e-05, 'epochs': 7, 'batch_size': 16}
# Epoch 1 | Train Loss: 0.1107 | Train Accuracy: 0.9670
# Validation Loss: 0.1238 | Validation Accuracy: 0.9688
# Time: 160.85 seconds
# Epoch 2 | Train Loss: 0.0477 | Train Accuracy: 0.9882
# Validation Loss: 0.1041 | Validation Accuracy: 0.9688
# Time: 160.83 seconds
# Epoch 3 | Train Loss: 0.0370 | Train Accuracy: 0.9917
# Validation Loss: 0.1182 | Validation Accuracy: 0.9732
# Time: 160.46 seconds
# New best model saved with accuracy: 0.9732
# Epoch 4 | Train Loss: 0.0251 | Train Accuracy: 0.9942
# Validation Loss: 0.1119 | Validation Accuracy: 0.9777
# Time: 161.09 seconds
# New best model saved with accuracy: 0.9777
# Epoch 5 | Train Loss: 0.0200 | Train Accuracy: 0.9960
# Validation Loss: 0.1074 | Validation Accuracy: 0.9768
# Time: 160.70 seconds
# Epoch 6 | Train Loss: 0.0177 | Train Accuracy: 0.9967
# Validation Loss: 0.1076 | Validation Accuracy: 0.9759
# Time: 160.97 seconds
# Epoch 7 | Train Loss: 0.0143 | Train Accuracy: 0.9978
# Validation Loss: 0.1021 | Validation Accuracy: 0.9759
# Time: 161.13 seconds
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       959
#            1       0.93      0.89      0.91       156
#
#     accuracy                           0.98      1115
#    macro avg       0.96      0.94      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0144 | Train Accuracy: 0.9973
# Validation Loss: 0.1020 | Validation Accuracy: 0.9759
# Time: 154.49 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0129 | Train Accuracy: 0.9978
# Validation Loss: 0.1021 | Validation Accuracy: 0.9768
# Time: 153.75 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0148 | Train Accuracy: 0.9975
# Validation Loss: 0.1021 | Validation Accuracy: 0.9768
# Time: 154.30 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0152 | Train Accuracy: 0.9971
# Validation Loss: 0.1020 | Validation Accuracy: 0.9768
# Time: 154.16 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 3e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0130 | Train Accuracy: 0.9978
# Validation Loss: 0.1020 | Validation Accuracy: 0.9768
# Time: 154.33 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 1
# Train Loss: 0.1090 | Train Accuracy: 0.9720
# Validation Loss: 0.1649 | Validation Accuracy: 0.9598
# Time: 168.53 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 2
# Train Loss: 0.0683 | Train Accuracy: 0.9823
# Validation Loss: 0.1616 | Validation Accuracy: 0.9643
# Time: 168.97 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 3
# Train Loss: 0.0320 | Train Accuracy: 0.9926
# Validation Loss: 0.1319 | Validation Accuracy: 0.9705
# Time: 169.02 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 4
# Train Loss: 0.0198 | Train Accuracy: 0.9957
# Validation Loss: 0.1295 | Validation Accuracy: 0.9696
# Time: 168.84 seconds
# --------------------------------------------------
# Optimizer: adam | Learning Rate: 5e-05 | Batch Size: 16
# Epoch 5
# Train Loss: 0.0139 | Train Accuracy: 0.9973
# Validation Loss: 0.1399 | Validation Accuracy: 0.9705
# Time: 169.16 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 1
# Train Loss: 0.0364 | Train Accuracy: 0.9917
# Validation Loss: 0.1775 | Validation Accuracy: 0.9679
# Time: 171.01 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 2
# Train Loss: 0.0177 | Train Accuracy: 0.9966
# Validation Loss: 0.1448 | Validation Accuracy: 0.9714
# Time: 171.20 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 3
# Train Loss: 0.0128 | Train Accuracy: 0.9973
# Validation Loss: 0.1834 | Validation Accuracy: 0.9688
# Time: 171.20 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 4
# Train Loss: 0.0111 | Train Accuracy: 0.9980
# Validation Loss: 0.1752 | Validation Accuracy: 0.9696
# Time: 171.26 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 3e-05 | Batch Size: 16
# Epoch 5
# Train Loss: 0.0092 | Train Accuracy: 0.9984
# Validation Loss: 0.1782 | Validation Accuracy: 0.9705
# Time: 171.06 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0084 | Train Accuracy: 0.9984
# Validation Loss: 0.1779 | Validation Accuracy: 0.9696
# Time: 154.12 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0084 | Train Accuracy: 0.9989
# Validation Loss: 0.1779 | Validation Accuracy: 0.9696
# Time: 154.14 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0096 | Train Accuracy: 0.9987
# Validation Loss: 0.1777 | Validation Accuracy: 0.9696
# Time: 153.92 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0123 | Train Accuracy: 0.9973
# Validation Loss: 0.1777 | Validation Accuracy: 0.9696
# Time: 154.03 seconds
# --------------------------------------------------
# Optimizer: sgd | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0097 | Train Accuracy: 0.9980
# Validation Loss: 0.1778 | Validation Accuracy: 0.9696
# Time: 154.40 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 1
# Train Loss: 0.0258 | Train Accuracy: 0.9946
# Validation Loss: 0.1989 | Validation Accuracy: 0.9670
# Time: 161.20 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 2
# Train Loss: 0.0150 | Train Accuracy: 0.9978
# Validation Loss: 0.1953 | Validation Accuracy: 0.9688
# Time: 160.35 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 3
# Train Loss: 0.0240 | Train Accuracy: 0.9953
# Validation Loss: 0.1625 | Validation Accuracy: 0.9705
# Time: 160.75 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 4
# Train Loss: 0.0128 | Train Accuracy: 0.9973
# Validation Loss: 0.1880 | Validation Accuracy: 0.9679
# Time: 160.83 seconds
# --------------------------------------------------
# Optimizer: adamw | Learning Rate: 5e-05 | Batch Size: 32
# Epoch 5
# Train Loss: 0.0078 | Train Accuracy: 0.9982
# Validation Loss: 0.1606 | Validation Accuracy: 0.9714
# Time: 160.60 seconds
# --------------------------------------------------
# Best Validation Accuracy: 0.9768
# Best Parameters: Optimizer = sgd, Learning Rate = 3e-05, Batch Size = 32

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix,
    classification_report, roc_curve
)
import matplotlib.pyplot as plt
import numpy as np
import torch

def evaluate_binary_model(model, dataloader, device):
    model.eval()
    all_true_labels = []
    all_probs = []

    with torch.no_grad():
        for batch in dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            outputs = model(b_input_ids, b_input_mask)
            probs = torch.softmax(outputs, dim=1)

            all_true_labels.append(b_labels.cpu().numpy())
            all_probs.append(probs.cpu().numpy())

    # Convert to numpy
    all_true_labels = np.concatenate(all_true_labels)
    all_probs = np.concatenate(all_probs)
    all_preds = np.argmax(all_probs, axis=1)

    # ================= Metrics =================
    tn, fp, fn, tp = confusion_matrix(all_true_labels, all_preds).ravel()

    accuracy = accuracy_score(all_true_labels, all_preds)
    precision = precision_score(all_true_labels, all_preds)
    recall = recall_score(all_true_labels, all_preds)          # Sensitivity
    specificity = tn / (tn + fp)
    f1 = f1_score(all_true_labels, all_preds)
    auc = roc_auc_score(all_true_labels, all_probs[:, 1])

    # ================= Print metrics =================
    print("===== Evaluation Metrics =====")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"Sensitivity : {recall:.4f}")
    print(f"Specificity : {specificity:.4f}")
    print(f"F1-score    : {f1:.4f}")
    print(f"AUC         : {auc:.4f}")

    # ================= Classification Report =================
    print("\n===== Classification Report =====")
    print(classification_report(all_true_labels, all_preds, digits=4))

    # ================= ROC Curve (Both Classes) =================
    fpr_0, tpr_0, _ = roc_curve(all_true_labels, all_probs[:, 0], pos_label=0)
    fpr_1, tpr_1, _ = roc_curve(all_true_labels, all_probs[:, 1], pos_label=1)

    auc_0 = roc_auc_score(1 - all_true_labels, all_probs[:, 0])
    auc_1 = roc_auc_score(all_true_labels, all_probs[:, 1])

    plt.figure(figsize=(7, 6))
    plt.plot(fpr_0, tpr_0, label=f"Class 0 ROC (AUC = {auc_0:.2f})", lw=2)
    plt.plot(fpr_1, tpr_1, label=f"Class 1 ROC (AUC = {auc_1:.2f})", lw=2)
    plt.plot([0, 1], [0, 1], 'k--', lw=2)

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve for Binary Classification")
    plt.legend(loc="lower right")
    plt.grid()
    plt.tight_layout()
    plt.show()

    return accuracy, precision, recall, specificity, f1, auc


accuracy, precision, recall, specificity, f1, auc = evaluate_binary_model(
    model, val_dataloader, device
)
# Out:
# ===== Evaluation Metrics =====
# Accuracy     : 0.9713
# Precision    : 0.9366
# Recall       : 0.8526
# Sensitivity : 0.8526
# Specificity : 0.9906
# F1-score    : 0.8926
# AUC         : 0.9335
#
# ===== Classification Report =====
#               precision    recall  f1-score   support
#
#            0     0.9764    0.9906    0.9834       959
#            1     0.9366    0.8526    0.8926       156
#
#     accuracy                         0.9713      1115
#    macro avg     0.9565    0.9216    0.9380      1115
# weighted avg     0.9708    0.9713    0.9707      1115

# %% [markdown]
# # **4 Different Circuits**

# %%
import re, time, random, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
from transformers import AutoTokenizer, AutoModel
from torch.optim import AdamW

import nltk
from nltk.corpus import stopwords

warnings.filterwarnings("ignore")
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))


df = pd.read_csv("/kaggle/input/spam-dataset-qtl/spamdata_v2 (1).csv")

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    words = [w for w in text.split() if w not in stop_words]
    return " ".join(words)

df["cleaned_text"] = df["text"].astype(str).apply(clean_text)

le = LabelEncoder()
df["label"] = le.fit_transform(df["label"])
min_class = df["label"].value_counts().min()

df_balanced = (
    df.groupby("label", group_keys=False)
      .apply(lambda x: x.sample(min_class, random_state=42))
      .sample(frac=1, random_state=42)
)

print(df_balanced["label"].value_counts())
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-base")

tokens = tokenizer(
    df_balanced["cleaned_text"].tolist(),
    padding="max_length",
    truncation=True,
    max_length=128,
    return_tensors="pt"
)

input_ids = tokens["input_ids"]
attention_mask = tokens["attention_mask"]
labels = torch.tensor(df_balanced["label"].values)
X_train, X_val, y_train, y_val, m_train, m_val = train_test_split(
    input_ids, labels, attention_mask, test_size=0.2, random_state=42
)

train_data = TensorDataset(X_train, m_train, y_train)
val_data = TensorDataset(X_val, m_val, y_val)

train_loader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=16)
val_loader = DataLoader(val_data, sampler=SequentialSampler(val_data), batch_size=16)
dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev, interface="torch")
def qc1(weights, x):
    qml.Hadamard(0)
    qml.Hadamard(1)
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([0,1])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc2(weights, x):
    qml.Hadamard(0)
    qml.RY(x[0], 0)
    qml.RX(x[1], 1)
    qml.CNOT([1,0])
    qml.RX(weights[0], 0)
    qml.RY(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc3(weights, x):
    for i in range(2):
        qml.Hadamard(i)
        qml.RX(x[i], i)
        qml.RY(weights[i], i)
        qml.RZ(weights[i], i)
    qml.CNOT([0,1])
    return qml.expval(qml.PauliZ(1))

@qml.qnode(dev, interface="torch")
def qc4(weights, x):
    qml.Hadamard(0)
    qml.CNOT([0,1])
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([1,0])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

QUANTUM_CIRCUITS = {
    "QC1": qc1,
    "QC2": qc2,
    "QC3": qc3,
    "QC4": qc4
}
class QBiLSTM(nn.Module):
    def __init__(self, quantum_circuit):
        super().__init__()
        self.qc = quantum_circuit
        self.q_weights = nn.Parameter(torch.randn(2))

        self.encoder = AutoModel.from_pretrained("microsoft/deberta-v3-base")

        self.bilstm = nn.LSTM(
            input_size=768,
            hidden_size=128,
            bidirectional=True,
            batch_first=True
        )

        self.fc = nn.Linear(256, 2)

    def quantum_layer(self, x):
        q_outs = []
        for v in x:
            q_outs.append(self.qc(self.q_weights, v[:2]))
        return torch.stack(q_outs)

    def forward(self, input_ids, attention_mask):
        enc = self.encoder(input_ids, attention_mask).last_hidden_state
        lstm_out, _ = self.bilstm(enc)
        h = lstm_out[:, -1, :]

        _ = self.quantum_layer(h)  # quantum interaction

        return self.fc(h)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
results = {}

for name, qc in QUANTUM_CIRCUITS.items():
    print(f"\n====== Training {name} ======")

    model = QBiLSTM(qc).to(device)
    optimizer = AdamW(model.parameters(), lr=2e-5)
    loss_fn = nn.CrossEntropyLoss()

    for epoch in range(10):
        print(f"\n--- Epoch {epoch+1}/10 ---")
        model.train()
        total_loss = 0

        for step, batch in enumerate(train_loader, 1):
            ids, mask, y = [b.to(device) for b in batch]

            optimizer.zero_grad()
            out = model(ids, mask)
            loss = loss_fn(out, y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            if step % 50 == 0:  # print every 50 steps
                print(f"Step {step}: Loss = {loss.item():.4f}")

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1} finished. Avg Loss = {avg_loss:.4f}")

    # Evaluation
    model.eval()
    preds, gold = [], []
    with torch.no_grad():
        for batch in val_loader:
            ids, mask, y = [b.to(device) for b in batch]
            logits = model(ids, mask)
            preds.extend(torch.argmax(logits, 1).cpu().numpy())
            gold.extend(y.cpu().numpy())

    acc = accuracy_score(gold, preds)
    results[name] = acc

    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(gold, preds))

print("\n===== FINAL QUANTUM CIRCUIT COMPARISON =====")
for k, v in results.items():
    print(f"{k}: {v:.4f}")
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# label
# 1    747
# 0    747
# Name: count, dtype: int64
#
# ====== Training QC1 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.5693
# Epoch 1 finished. Avg Loss = 0.4906
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.2831
# Epoch 2 finished. Avg Loss = 0.3276
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.4386
# Epoch 3 finished. Avg Loss = 0.2632
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0418
# Epoch 4 finished. Avg Loss = 0.2093
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0590
# Epoch 5 finished. Avg Loss = 0.1671
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.1748
# Epoch 6 finished. Avg Loss = 0.1798
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.1798
# Epoch 7 finished. Avg Loss = 0.1217
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0210
# Epoch 8 finished. Avg Loss = 0.1011
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.1221
# Epoch 9 finished. Avg Loss = 0.1047
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0126
# Epoch 10 finished. Avg Loss = 0.1034
# QC1 Accuracy: 0.9632
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       155
#            1       0.99      0.94      0.96       144
#
#     accuracy                           0.96       299
#    macro avg       0.96      0.96      0.96       299
# weighted avg       0.96      0.96      0.96       299
#
#
# ====== Training QC2 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.2433
# Epoch 1 finished. Avg Loss = 0.4186
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.1187
# Epoch 2 finished. Avg Loss = 0.2386
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.2834
# Epoch 3 finished. Avg Loss = 0.1739
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0475
# Epoch 4 finished. Avg Loss = 0.2025
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0301
# Epoch 5 finished. Avg Loss = 0.1509
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.3748
# Epoch 6 finished. Avg Loss = 0.1483
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0220
# Epoch 7 finished. Avg Loss = 0.0805
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0135
# Epoch 8 finished. Avg Loss = 0.0794
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0122
# Epoch 9 finished. Avg Loss = 0.0671
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0185
# Epoch 10 finished. Avg Loss = 0.0533
# QC2 Accuracy: 0.9666
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       155
#            1       0.97      0.96      0.97       144
#
#     accuracy                           0.97       299
#    macro avg       0.97      0.97      0.97       299
# weighted avg       0.97      0.97      0.97       299
#
#
# ====== Training QC3 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.1931
# Epoch 1 finished. Avg Loss = 0.4143
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.6001
# Epoch 2 finished. Avg Loss = 0.2961
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.4345
# Epoch 3 finished. Avg Loss = 0.1791
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.1180
# Epoch 4 finished. Avg Loss = 0.1835
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0556
# Epoch 5 finished. Avg Loss = 0.1592
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0386
# Epoch 6 finished. Avg Loss = 0.1136
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.1940
# Epoch 7 finished. Avg Loss = 0.1219
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.0152
# Epoch 8 finished. Avg Loss = 0.0890
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0150
# Epoch 9 finished. Avg Loss = 0.0850
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0111
# Epoch 10 finished. Avg Loss = 0.1516
# QC3 Accuracy: 0.9465
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       155
#            1       0.98      0.91      0.94       144
#
#     accuracy                           0.95       299
#    macro avg       0.95      0.95      0.95       299
# weighted avg       0.95      0.95      0.95       299
#
#
# ====== Training QC4 ======
#
# --- Epoch 1/10 ---
# Step 50: Loss = 0.4201
# Epoch 1 finished. Avg Loss = 0.4128
#
# --- Epoch 2/10 ---
# Step 50: Loss = 0.2588
# Epoch 2 finished. Avg Loss = 0.2591
#
# --- Epoch 3/10 ---
# Step 50: Loss = 0.0942
# Epoch 3 finished. Avg Loss = 0.2090
#
# --- Epoch 4/10 ---
# Step 50: Loss = 0.0491
# Epoch 4 finished. Avg Loss = 0.1335
#
# --- Epoch 5/10 ---
# Step 50: Loss = 0.0649
# Epoch 5 finished. Avg Loss = 0.1547
#
# --- Epoch 6/10 ---
# Step 50: Loss = 0.0711
# Epoch 6 finished. Avg Loss = 0.1239
#
# --- Epoch 7/10 ---
# Step 50: Loss = 0.0223
# Epoch 7 finished. Avg Loss = 0.1202
#
# --- Epoch 8/10 ---
# Step 50: Loss = 0.2407
# Epoch 8 finished. Avg Loss = 0.1193
#
# --- Epoch 9/10 ---
# Step 50: Loss = 0.0314
# Epoch 9 finished. Avg Loss = 0.0913
#
# --- Epoch 10/10 ---
# Step 50: Loss = 0.0155
# Epoch 10 finished. Avg Loss = 0.0837
# QC4 Accuracy: 0.9365
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94       155
#            1       0.90      0.97      0.94       144
#
#     accuracy                           0.94       299
#    macro avg       0.94      0.94      0.94       299
# weighted avg       0.94      0.94      0.94       299
#
#
# ===== FINAL QUANTUM CIRCUIT COMPARISON =====
# QC1: 0.9632
# QC2: 0.9666
# QC3: 0.9465
# QC4: 0.9365

# %%
qml.draw_mpl(qc1,default='sketch')(np.array([0.1, 0.2]), np.array([0.3, 0.4]))
qml.draw_mpl(qc2,default='pennylane')(np.array([0.1, 0.2]), np.array([0.3, 0.4]))
qml.draw_mpl(qc3,default='pennylane')(np.array([0.1, 0.2]), np.array([0.3, 0.4]))
qml.draw_mpl(qc4,default='pennylane')(np.array([0.1, 0.2]), np.array([0.3, 0.4]))
# Out:
# (<Figure size 800x300 with 1 Axes>, <Axes: >)

# %%
# !pip install pennylane
# =========================
# 1. Imports
# =========================
import re, time, random, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import pennylane as qml
from torch.optim import AdamW
from sklearn.model_selection import train_test_split, ParameterSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler
from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup

import nltk
from nltk.corpus import stopwords

warnings.filterwarnings("ignore")
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================
# 2. Load & Clean Dataset
# =========================
df = pd.read_csv("/kaggle/input/spam-dataset-qtl/spamdata_v2 (1).csv")

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    words = [w for w in text.split() if w not in stop_words]
    return " ".join(words)

df["cleaned_text"] = df["text"].astype(str).apply(clean_text)

le = LabelEncoder()
df["label"] = le.fit_transform(df["label"])

# Balance classes
min_class = df["label"].value_counts().min()
df = (
    df.groupby("label", group_keys=False)
      .apply(lambda x: x.sample(min_class, random_state=42))
      .sample(frac=1, random_state=42)
)

# =========================
# 3. Tokenization
# =========================
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-base")

tokens = tokenizer(
    df["cleaned_text"].tolist(),
    padding="max_length",
    truncation=True,
    max_length=128,
    return_tensors="pt"
)

input_ids = tokens["input_ids"]
attention_mask = tokens["attention_mask"]
labels = torch.tensor(df["label"].values)

X_train, X_val, y_train, y_val, m_train, m_val = train_test_split(
    input_ids, labels, attention_mask, test_size=0.2, random_state=42
)

train_data = TensorDataset(X_train, m_train, y_train)
val_data   = TensorDataset(X_val, m_val, y_val)

# =========================
# 4. Quantum Circuits
# =========================
dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev, interface="torch")
def qc1(weights, x):
    qml.Hadamard(0)
    qml.Hadamard(1)
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([0, 1])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc2(weights, x):
    qml.Hadamard(0)
    qml.RY(x[0], 0)
    qml.RX(x[1], 1)
    qml.CNOT([1, 0])
    qml.RX(weights[0], 0)
    qml.RY(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

@qml.qnode(dev, interface="torch")
def qc3(weights, x):
    for i in range(2):
        qml.Hadamard(i)
        qml.RX(x[i], i)
        qml.RY(weights[i], i)
        qml.RZ(weights[i], i)
    qml.CNOT([0, 1])
    return qml.expval(qml.PauliZ(1))

@qml.qnode(dev, interface="torch")
def qc4(weights, x):
    qml.Hadamard(0)
    qml.CNOT([0, 1])
    qml.RX(x[0], 0)
    qml.RY(x[1], 1)
    qml.CNOT([1, 0])
    qml.RZ(weights[0], 0)
    qml.RZ(weights[1], 1)
    return qml.expval(qml.PauliZ(0))

QUANTUM_CIRCUITS = {
    "QC1": qc1,
    "QC2": qc2,
    "QC3": qc3,
    "QC4": qc4
}

# =========================
# 5. QBiLSTM Model
# =========================
class QBiLSTM(nn.Module):
    def __init__(self, quantum_circuit):
        super().__init__()
        self.qc = quantum_circuit
        self.q_weights = nn.Parameter(torch.randn(2))

        self.encoder = AutoModel.from_pretrained("microsoft/deberta-v3-base")

        self.bilstm = nn.LSTM(
            input_size=768,
            hidden_size=128,
            bidirectional=True,
            batch_first=True
        )

        self.fc = nn.Linear(257, 2)  # 256 + quantum feature

    def quantum_layer(self, x):
        q_out = [self.qc(self.q_weights, v[:2]) for v in x]
        q_out = torch.stack(q_out).unsqueeze(1)
        return q_out.float()

    def forward(self, input_ids, attention_mask):
        enc = self.encoder(input_ids, attention_mask).last_hidden_state
        lstm_out, _ = self.bilstm(enc)
        h = lstm_out[:, -1, :]

        q_feat = self.quantum_layer(h)
        h = torch.cat([h, q_feat], dim=1)

        return self.fc(h)

# =========================
# 6. Training Function
# =========================
def train_and_validate(model, params):
    train_loader = DataLoader(
        train_data, sampler=RandomSampler(train_data),
        batch_size=params["batch_size"]
    )
    val_loader = DataLoader(
        val_data, sampler=SequentialSampler(val_data),
        batch_size=params["batch_size"]
    )

    optimizer = AdamW(model.parameters(), lr=params["learning_rate"])
    loss_fn = nn.CrossEntropyLoss()

    total_steps = len(train_loader) * params["epochs"]
    scheduler = get_linear_schedule_with_warmup(
        optimizer, 0, total_steps
    )

    for _ in range(params["epochs"]):
        model.train()
        for ids, mask, y in train_loader:
            ids, mask, y = ids.to(device), mask.to(device), y.to(device)

            optimizer.zero_grad()
            loss = loss_fn(model(ids, mask), y)
            loss.backward()
            optimizer.step()
            scheduler.step()

    model.eval()
    preds, gold = [], []
    with torch.no_grad():
        for ids, mask, y in val_loader:
            ids, mask = ids.to(device), mask.to(device)
            logits = model(ids, mask)
            preds.extend(torch.argmax(logits, 1).cpu().numpy())
            gold.extend(y.numpy())

    return accuracy_score(gold, preds)

# =========================
# 7. Hyperparameter Search
# =========================
param_grid = {
    "learning_rate": [1e-5, 2e-5, 3e-5],
    "batch_size": [16, 32],
    "epochs": [3, 5]
}

param_list = list(ParameterSampler(param_grid, n_iter=5, random_state=42))

final_results = {}

for name, qc in QUANTUM_CIRCUITS.items():
    print(f"\n===== {name} =====")

    best_acc = 0
    best_params = None

    for params in param_list:
        model = QBiLSTM(qc).to(device)
        acc = train_and_validate(model, params)

        print(f"{params} → Acc: {acc:.4f}")

        if acc > best_acc:
            best_acc = acc
            best_params = params

    final_results[name] = (best_acc, best_params)

# =========================
# 8. Final Results
# =========================
print("\n===== FINAL COMPARISON =====")
for k, (acc, params) in final_results.items():
    print(f"{k}: Accuracy = {acc:.4f}, Params = {params}")
# Out:
# Collecting pennylane
#   Downloading pennylane-0.44.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane)
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.44 (from pennylane)
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.0rc2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane)
#   Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.44.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 60.7 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 55.5 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 75.2 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 84.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 7.2 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 99.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 pennylane-0.44.0 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.22.1
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# ===== QC1 =====
# 2026-02-09 15:01:57.837727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770649318.071865      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770649318.139688      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770649318.692461      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770649318.692488      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770649318.692491      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770649318.692494      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/371M [00:00<?, ?B/s]
# {'learning_rate': 2e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9599
# {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9532
# {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16} → Acc: 0.9365
# {'learning_rate': 3e-05, 'epochs': 3, 'batch_size': 32} → Acc: 0.9565
# {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16} → Acc: 0.9599
#
# ===== QC2 =====
# {'learning_rate': 2e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9431
# {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9599
# {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16} → Acc: 0.9465
# {'learning_rate': 3e-05, 'epochs': 3, 'batch_size': 32} → Acc: 0.9465
# {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16} → Acc: 0.9699
#
# ===== QC3 =====
# {'learning_rate': 2e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9465
# {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9498
# {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16} → Acc: 0.9365
# {'learning_rate': 3e-05, 'epochs': 3, 'batch_size': 32} → Acc: 0.9632
# {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16} → Acc: 0.9632
#
# ===== QC4 =====
# {'learning_rate': 2e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9532
# {'learning_rate': 1e-05, 'epochs': 5, 'batch_size': 32} → Acc: 0.9599
# {'learning_rate': 1e-05, 'epochs': 3, 'batch_size': 16} → Acc: 0.9532
# {'learning_rate': 3e-05, 'epochs': 3, 'batch_size': 32} → Acc: 0.9565
# {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16} → Acc: 0.9666
#
# ===== FINAL COMPARISON =====
# QC1: Accuracy = 0.9599, Params = {'learning_rate': 2e-05, 'epochs': 5, 'batch_size': 32}
# QC2: Accuracy = 0.9699, Params = {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16}
# QC3: Accuracy = 0.9632, Params = {'learning_rate': 3e-05, 'epochs': 3, 'batch_size': 32}
# QC4: Accuracy = 0.9666, Params = {'learning_rate': 3e-05, 'epochs': 5, 'batch_size': 16}

# %%
epochs = 5
learning_rates = [2e-5, 3e-5, 5e-5]
batch_sizes = [16, 32]
optimizers = ['adamw', 'adam', 'rmsprop', 'sgd']
num_samples = 5
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def get_optimizer(optimizer_name, model_parameters, lr):
    if optimizer_name == 'adamw':
        return optim.AdamW(model_parameters, lr=lr)
    elif optimizer_name == 'adam':
        return optim.Adam(model_parameters, lr=lr)
    elif optimizer_name == 'rmsprop':
        return optim.RMSprop(model_parameters, lr=lr)
    elif optimizer_name == 'sgd':
        return optim.SGD(model_parameters, lr=lr)
final_results = {}

for qc_name, qc in QUANTUM_CIRCUITS.items():
    print(f"\n==============================")
    print(f" Quantum Circuit: {qc_name}")
    print(f"==============================")

    best_accuracy = 0
    best_params = None

    # Random hyperparameter sampling
    random_hyperparams = [
        {
            "optimizer": random.choice(optimizers),
            "learning_rate": random.choice(learning_rates),
            "batch_size": random.choice(batch_sizes),
        }
        for _ in range(num_samples)
    ]

    for params in random_hyperparams:
        optimizer_name = params["optimizer"]
        lr = params["learning_rate"]
        batch_size = params["batch_size"]

        print(f"\n Testing {params}")

        # Fresh model for each trial (VERY IMPORTANT)
        model = QBiLSTM(qc).to(device)

        train_dataloader = DataLoader(
            train_data,
            sampler=RandomSampler(train_data),
            batch_size=batch_size
        )

        val_dataloader = DataLoader(
            val_data,
            sampler=SequentialSampler(val_data),
            batch_size=batch_size
        )

        optimizer = get_optimizer(optimizer_name, model.parameters(), lr)
        loss_fn = nn.CrossEntropyLoss()

        total_steps = len(train_dataloader) * epochs
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=0,
            num_training_steps=total_steps
        )

        # ===== Training =====
        for epoch in range(epochs):
            model.train()
            total_train_loss = 0
            total_train_accuracy = 0

            for batch in train_dataloader:
                b_input_ids, b_input_mask, b_labels = batch
                b_input_ids = b_input_ids.to(device)
                b_input_mask = b_input_mask.to(device)
                b_labels = b_labels.to(device)

                optimizer.zero_grad()
                outputs = model(b_input_ids, b_input_mask)
                loss = loss_fn(outputs, b_labels)

                total_train_loss += loss.item()
                logits = outputs.detach().cpu().numpy()
                total_train_accuracy += flat_accuracy(logits, b_labels.cpu().numpy())

                loss.backward()
                optimizer.step()
                scheduler.step()

            avg_train_loss = total_train_loss / len(train_dataloader)
            avg_train_accuracy = total_train_accuracy / len(train_dataloader)

            # ===== Validation =====
            model.eval()
            total_val_accuracy = 0
            total_val_loss = 0

            with torch.no_grad():
                for batch in val_dataloader:
                    b_input_ids, b_input_mask, b_labels = batch
                    b_input_ids = b_input_ids.to(device)
                    b_input_mask = b_input_mask.to(device)
                    b_labels = b_labels.to(device)

                    outputs = model(b_input_ids, b_input_mask)
                    loss = loss_fn(outputs, b_labels)

                    total_val_loss += loss.item()
                    logits = outputs.detach().cpu().numpy()
                    total_val_accuracy += flat_accuracy(logits, b_labels.cpu().numpy())

            avg_val_accuracy = total_val_accuracy / len(val_dataloader)

            print(
                f"Epoch {epoch+1} | "
                f"Train Acc: {avg_train_accuracy:.4f} | "
                f"Val Acc: {avg_val_accuracy:.4f}"
            )

        # ===== Track best =====
        if avg_val_accuracy > best_accuracy:
            best_accuracy = avg_val_accuracy
            best_params = {
                "optimizer": optimizer_name,
                "learning_rate": lr,
                "batch_size": batch_size
            }

    final_results[qc_name] = {
        "best_accuracy": best_accuracy,
        "best_params": best_params
    }

    print(f"\n BEST for {qc_name}: {best_accuracy:.4f}")
    print(f" PARAMS: {best_params}")

print("\n===== FINAL QUANTUM CIRCUIT COMPARISON =====")
for qc, res in final_results.items():
    print(
        f"{qc} | Accuracy: {res['best_accuracy']:.4f} | "
        f"Params: {res['best_params']}"
    )
# Out:
# ==============================
#  Quantum Circuit: QC1
# ==============================
#
#  Testing {'optimizer': 'adam', 'learning_rate': 2e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.8076 | Val Acc: 0.9437
# Epoch 2 | Train Acc: 0.9236 | Val Acc: 0.9437
# Epoch 3 | Train Acc: 0.9383 | Val Acc: 0.9563
# Epoch 4 | Train Acc: 0.9350 | Val Acc: 0.9594
# Epoch 5 | Train Acc: 0.9515 | Val Acc: 0.9594
#
#  Testing {'optimizer': 'rmsprop', 'learning_rate': 3e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.8000 | Val Acc: 0.9327
# Epoch 2 | Train Acc: 0.9383 | Val Acc: 0.9737
# Epoch 3 | Train Acc: 0.9667 | Val Acc: 0.9737
# Epoch 4 | Train Acc: 0.9767 | Val Acc: 0.9737
# Epoch 5 | Train Acc: 0.9850 | Val Acc: 0.9572
#
#  Testing {'optimizer': 'sgd', 'learning_rate': 2e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.7547 | Val Acc: 0.6914
# Epoch 2 | Train Acc: 0.7701 | Val Acc: 0.7045
# Epoch 3 | Train Acc: 0.7860 | Val Acc: 0.7587
# Epoch 4 | Train Acc: 0.8046 | Val Acc: 0.7374
# Epoch 5 | Train Acc: 0.8000 | Val Acc: 0.7653
#
#  Testing {'optimizer': 'rmsprop', 'learning_rate': 2e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.5860 | Val Acc: 0.5455
# Epoch 2 | Train Acc: 0.9244 | Val Acc: 0.9625
# Epoch 3 | Train Acc: 0.9565 | Val Acc: 0.9688
# Epoch 4 | Train Acc: 0.9688 | Val Acc: 0.9688
# Epoch 5 | Train Acc: 0.9811 | Val Acc: 0.9688
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 3e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.6859 | Val Acc: 0.8909
# Epoch 2 | Train Acc: 0.9244 | Val Acc: 0.9315
# Epoch 3 | Train Acc: 0.9507 | Val Acc: 0.9750
# Epoch 4 | Train Acc: 0.9688 | Val Acc: 0.9781
# Epoch 5 | Train Acc: 0.9754 | Val Acc: 0.9781
#
#  BEST for QC1: 0.9781
#  PARAMS: {'optimizer': 'adamw', 'learning_rate': 3e-05, 'batch_size': 32}
#
# ==============================
#  Quantum Circuit: QC2
# ==============================
#
#  Testing {'optimizer': 'sgd', 'learning_rate': 3e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.5068 | Val Acc: 0.5287
# Epoch 2 | Train Acc: 0.5656 | Val Acc: 0.5781
# Epoch 3 | Train Acc: 0.5898 | Val Acc: 0.6106
# Epoch 4 | Train Acc: 0.6185 | Val Acc: 0.6403
# Epoch 5 | Train Acc: 0.6260 | Val Acc: 0.6468
#
#  Testing {'optimizer': 'adam', 'learning_rate': 2e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.8380 | Val Acc: 0.9375
# Epoch 2 | Train Acc: 0.9048 | Val Acc: 0.9344
# Epoch 3 | Train Acc: 0.9400 | Val Acc: 0.9594
# Epoch 4 | Train Acc: 0.9465 | Val Acc: 0.9625
# Epoch 5 | Train Acc: 0.9597 | Val Acc: 0.9625
#
#  Testing {'optimizer': 'rmsprop', 'learning_rate': 3e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.8621 | Val Acc: 0.9243
# Epoch 2 | Train Acc: 0.9583 | Val Acc: 0.9671
# Epoch 3 | Train Acc: 0.9767 | Val Acc: 0.9572
# Epoch 4 | Train Acc: 0.9817 | Val Acc: 0.9737
# Epoch 5 | Train Acc: 0.9908 | Val Acc: 0.9638
#
#  Testing {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.7723 | Val Acc: 0.9219
# Epoch 2 | Train Acc: 0.9194 | Val Acc: 0.9437
# Epoch 3 | Train Acc: 0.9466 | Val Acc: 0.9594
# Epoch 4 | Train Acc: 0.9646 | Val Acc: 0.9656
# Epoch 5 | Train Acc: 0.9712 | Val Acc: 0.9656
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.7696 | Val Acc: 0.9327
# Epoch 2 | Train Acc: 0.9384 | Val Acc: 0.9557
# Epoch 3 | Train Acc: 0.9650 | Val Acc: 0.9638
# Epoch 4 | Train Acc: 0.9792 | Val Acc: 0.9737
# Epoch 5 | Train Acc: 0.9883 | Val Acc: 0.9671
#
#  BEST for QC2: 0.9671
#  PARAMS: {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}
#
# ==============================
#  Quantum Circuit: QC3
# ==============================
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 2e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.7954 | Val Acc: 0.9281
# Epoch 2 | Train Acc: 0.9293 | Val Acc: 0.9500
# Epoch 3 | Train Acc: 0.9228 | Val Acc: 0.9406
# Epoch 4 | Train Acc: 0.9483 | Val Acc: 0.9531
# Epoch 5 | Train Acc: 0.9540 | Val Acc: 0.9563
#
#  Testing {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.7724 | Val Acc: 0.9344
# Epoch 2 | Train Acc: 0.9326 | Val Acc: 0.9531
# Epoch 3 | Train Acc: 0.9301 | Val Acc: 0.9656
# Epoch 4 | Train Acc: 0.9524 | Val Acc: 0.9656
# Epoch 5 | Train Acc: 0.9679 | Val Acc: 0.9625
#
#  Testing {'optimizer': 'rmsprop', 'learning_rate': 5e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.6242 | Val Acc: 0.8095
# Epoch 2 | Train Acc: 0.8542 | Val Acc: 0.9211
# Epoch 3 | Train Acc: 0.9371 | Val Acc: 0.9557
# Epoch 4 | Train Acc: 0.9508 | Val Acc: 0.9378
# Epoch 5 | Train Acc: 0.9476 | Val Acc: 0.9378
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 2e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.8192 | Val Acc: 0.9112
# Epoch 2 | Train Acc: 0.8917 | Val Acc: 0.9309
# Epoch 3 | Train Acc: 0.9009 | Val Acc: 0.9375
# Epoch 4 | Train Acc: 0.9367 | Val Acc: 0.9276
# Epoch 5 | Train Acc: 0.9458 | Val Acc: 0.9441
#
#  Testing {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 32}
# Epoch 1 | Train Acc: 0.7830 | Val Acc: 0.9344
# Epoch 2 | Train Acc: 0.9104 | Val Acc: 0.9500
# Epoch 3 | Train Acc: 0.9367 | Val Acc: 0.9500
# Epoch 4 | Train Acc: 0.9523 | Val Acc: 0.9594
# Epoch 5 | Train Acc: 0.9646 | Val Acc: 0.9625
#
#  BEST for QC3: 0.9625
#  PARAMS: {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 32}
#
# ==============================
#  Quantum Circuit: QC4
# ==============================
#
#  Testing {'optimizer': 'adam', 'learning_rate': 5e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.8171 | Val Acc: 0.9342
# Epoch 2 | Train Acc: 0.9158 | Val Acc: 0.9408
# Epoch 3 | Train Acc: 0.9475 | Val Acc: 0.9539
# Epoch 4 | Train Acc: 0.9625 | Val Acc: 0.9572
# Epoch 5 | Train Acc: 0.9717 | Val Acc: 0.9605
#
#  Testing {'optimizer': 'rmsprop', 'learning_rate': 2e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.7475 | Val Acc: 0.9393
# Epoch 2 | Train Acc: 0.9471 | Val Acc: 0.9211
# Epoch 3 | Train Acc: 0.9663 | Val Acc: 0.9623
# Epoch 4 | Train Acc: 0.9775 | Val Acc: 0.9737
# Epoch 5 | Train Acc: 0.9817 | Val Acc: 0.9671
#
#  Testing {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.7884 | Val Acc: 0.8457
# Epoch 2 | Train Acc: 0.9171 | Val Acc: 0.9360
# Epoch 3 | Train Acc: 0.9425 | Val Acc: 0.9572
# Epoch 4 | Train Acc: 0.9613 | Val Acc: 0.9507
# Epoch 5 | Train Acc: 0.9717 | Val Acc: 0.9638
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.7692 | Val Acc: 0.9408
# Epoch 2 | Train Acc: 0.9175 | Val Acc: 0.9539
# Epoch 3 | Train Acc: 0.9646 | Val Acc: 0.9539
# Epoch 4 | Train Acc: 0.9642 | Val Acc: 0.9638
# Epoch 5 | Train Acc: 0.9792 | Val Acc: 0.9704
#
#  Testing {'optimizer': 'adamw', 'learning_rate': 2e-05, 'batch_size': 16}
# Epoch 1 | Train Acc: 0.8022 | Val Acc: 0.8917
# Epoch 2 | Train Acc: 0.9155 | Val Acc: 0.9441
# Epoch 3 | Train Acc: 0.9375 | Val Acc: 0.9082
# Epoch 4 | Train Acc: 0.9505 | Val Acc: 0.9572
# Epoch 5 | Train Acc: 0.9580 | Val Acc: 0.9638
#
#  BEST for QC4: 0.9704
#  PARAMS: {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}
#
# ===== FINAL QUANTUM CIRCUIT COMPARISON =====
# QC1 | Accuracy: 0.9781 | Params: {'optimizer': 'adamw', 'learning_rate': 3e-05, 'batch_size': 32}
# QC2 | Accuracy: 0.9671 | Params: {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}
# QC3 | Accuracy: 0.9625 | Params: {'optimizer': 'adam', 'learning_rate': 3e-05, 'batch_size': 32}
# QC4 | Accuracy: 0.9704 | Params: {'optimizer': 'adamw', 'learning_rate': 5e-05, 'batch_size': 16}

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    confusion_matrix
)
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import torch

# ----- Evaluation function -----
def evaluate_model(model, dataloader, num_classes):
    model.eval()

    all_logits = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)

            outputs = model(b_input_ids, b_input_mask)

            all_logits.append(outputs.cpu())
            all_labels.append(b_labels)

    logits = torch.cat(all_logits).numpy()
    labels = torch.cat(all_labels).numpy()

    probs = torch.softmax(torch.tensor(logits), dim=1).numpy()
    preds = np.argmax(probs, axis=1)

    # ---- Metrics ----
    accuracy = accuracy_score(labels, preds)
    precision = precision_score(labels, preds, average="macro")
    sensitivity = recall_score(labels, preds, average="macro")  # Recall
    f1 = f1_score(labels, preds, average="macro")

    # ---- Specificity ----
    cm = confusion_matrix(labels, preds)
    specificity_per_class = []
    for i in range(num_classes):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity_per_class.append(tn / (tn + fp + 1e-9))
    specificity = np.mean(specificity_per_class)

    # ---- AUC ----
    if num_classes == 2:
        auc = roc_auc_score(labels, probs[:, 1])  # binary case
    else:
        labels_bin = label_binarize(labels, classes=list(range(num_classes)))
        auc = roc_auc_score(labels_bin, probs, average="macro", multi_class="ovr")

    return {
        "accuracy": accuracy,
        "precision": precision,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "f1": f1,
        "auc": auc,
        "labels": labels,
        "probs": probs
    }

# ----- Number of classes -----
num_classes = len(torch.unique(train_data.tensors[2]))  # or 2 for binary

best_models_results = {}

# ----- Evaluate each best model -----
for qc_name, res in final_results.items():
    print(f"\nEvaluating BEST model for {qc_name}")

    params = res["best_params"]

    # Fresh model
    model = QBiLSTM(QUANTUM_CIRCUITS[qc_name]).to(device)

    train_loader = DataLoader(
        train_data,
        sampler=RandomSampler(train_data),
        batch_size=params["batch_size"]
    )

    val_loader = DataLoader(
        val_data,
        sampler=SequentialSampler(val_data),
        batch_size=params["batch_size"]
    )

    optimizer = get_optimizer(params["optimizer"], model.parameters(), params["learning_rate"])
    loss_fn = nn.CrossEntropyLoss()

    # ---- Retrain ----
    for epoch in range(epochs):
        model.train()
        for batch in train_loader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids, b_input_mask, b_labels = b_input_ids.to(device), b_input_mask.to(device), b_labels.to(device)

            optimizer.zero_grad()
            outputs = model(b_input_ids, b_input_mask)
            loss = loss_fn(outputs, b_labels)
            loss.backward()
            optimizer.step()

    # ---- Final Evaluation ----
    metrics = evaluate_model(model, val_loader, num_classes)
    best_models_results[qc_name] = metrics

# ----- Print Summary Table -----
print("\n===== FINAL PERFORMANCE COMPARISON =====")
print("Model | Accuracy | Precision | Sensitivity | Specificity | F1 | AUC")
print("-"*75)
for qc, m in best_models_results.items():
    print(f"{qc} | {m['accuracy']:.4f} | {m['precision']:.4f} | {m['sensitivity']:.4f} | {m['specificity']:.4f} | {m['f1']:.4f} | {m['auc']:.4f}")

# ----- Plot ROC Curves -----
for qc, m in best_models_results.items():
    labels = m["labels"]
    probs = m["probs"]

    plt.figure(figsize=(7,6))
    if num_classes == 2:
        fpr, tpr, _ = roc_curve(labels, probs[:,1])
        auc_score = roc_auc_score(labels, probs[:,1])
        plt.plot(fpr, tpr, label=f"AUC={auc_score:.3f}")
    else:
        labels_bin = label_binarize(labels, classes=list(range(num_classes)))
        for i in range(num_classes):
            fpr, tpr, _ = roc_curve(labels_bin[:, i], probs[:, i])
            auc_i = roc_auc_score(labels_bin[:, i], probs[:, i])
            plt.plot(fpr, tpr, label=f"Class {i} (AUC={auc_i:.3f})")

    plt.plot([0,1], [0,1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve – {qc}")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Evaluating BEST model for QC1
#
# Evaluating BEST model for QC2
#
# Evaluating BEST model for QC3
#
# Evaluating BEST model for QC4
#
# ===== FINAL PERFORMANCE COMPARISON =====
# Model | Accuracy | Precision | Sensitivity | Specificity | F1 | AUC
# ---------------------------------------------------------------------------
# QC1 | 0.9666 | 0.9664 | 0.9668 | 0.9668 | 0.9665 | 0.9886
# QC2 | 0.9632 | 0.9642 | 0.9625 | 0.9625 | 0.9631 | 0.9873
# QC3 | 0.9532 | 0.9530 | 0.9536 | 0.9536 | 0.9532 | 0.9863
# QC4 | 0.9231 | 0.9354 | 0.9201 | 0.9201 | 0.9221 | 0.9446
